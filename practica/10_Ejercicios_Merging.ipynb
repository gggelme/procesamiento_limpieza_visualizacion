# %% [markdown]
# # Ejercicios de Merging y Joins en Pandas 🔗
# En este cuaderno, practicarás cómo combinar DataFrames utilizando `merge`, `join` y otras técnicas de pandas.

# %% [markdown]
# ## Ejercicio 1: Merge básico
# - Importa los archivos `restaurant_customers.csv` y `restaurant_foods.csv` en dos DataFrames llamados `customers` y `foods`.
# - Realiza un merge entre ambos DataFrames usando la columna `Food ID`.
# - Muestra los primeros 5 registros del resultado.

# %%
import pandas as pd
customers = pd.read_csv('restaurant_customers.csv', sep=';')
foods = pd.read_csv('restaurant_foods.csv', sep=';')

# %% [markdown]
# ## Ejercicio 2: Merge con diferentes tipos de join
# - Realiza un merge entre `restaurant_week_1_sales.csv` y `restaurant_foods.csv` usando un `left join`.
# - Realiza un merge usando un `outer join`.
# - Muestra la cantidad de filas en cada resultado.

# %%
week1_sales = pd.read_csv('restaurant_week_1_sales.csv', sep=';')

# %% [markdown]
# ## Ejercicio 3: Merge con múltiples columnas
# - Importa el archivo `restaurant_week_2_sales.csv`.
# - Realiza un merge entre `restaurant_week_1_sales.csv` y `restaurant_week_2_sales.csv` usando las columnas `Customer ID` y `Food ID`.
# - Muestra los primeros 5 registros.

# %%
week2_sales = pd.read_csv('restaurant_week_2_sales.csv', sep=';')

# %% [markdown]
# ## Ejercicio 4: Uso del método join
# - Establece la columna `Customer ID` como índice en el DataFrame `restaurant_week_1_sales.csv`.
# - Establece la columna `Customer ID` como índice en el DataFrame `restaurant_week_2_sales.csv`.
# - Usa el método `join` para combinar ambos DataFrames.
# - Muestra los primeros 5 registros.

# %% [markdown]
# ## Ejercicio 5: Merge con sufijos
# - Crea dos DataFrames con una columna en común llamada `Nombre`.
# - Realiza un merge usando la columna `Nombre` y agrega sufijos para diferenciar las columnas repetidas.
# - Muestra el resultado.

# %%
df1 = pd.DataFrame({'Nombre': ['Ana', 'Luis', 'Carlos'], 'Edad': [23, 34, 45]})
df2 = pd.DataFrame({'Nombre': ['Ana', 'Luis', 'Carlos'], 'Ciudad': ['Madrid', 'Barcelona', 'Valencia']})

# %% [markdown]
# ## Ejercicio 6: Concatenación de DataFrames
# - Crea dos DataFrames con la misma estructura de columnas.
# - Concatena ambos DataFrames.
# - Muestra el resultado.

# %%
df_a = pd.DataFrame({'col1': ['A0', 'A1'], 'col2': ['A2', 'A3']})
df_b = pd.DataFrame({'col1': ['B0', 'B1'], 'col2': ['B2', 'B3']})
