# %%
import pandas as pd

# %% [markdown]
# # Enunciado del ejercicio 1: Booleanos en un DataFrame
# En este ejercicio trabajarás con el archivo `the_office.csv` que contiene las columnas: Season, Episode, Name, Director, Writer, Airdate, Viewership. Debes:
#
# - Importar el archivo CSV en un DataFrame llamado `office`, indicando que la columna `Airdate` sea interpretada como fecha.
# - Encontrar todos los episodios cuyo escritor sea "Greg Daniels" y asignarlos a `written_by_greg`.
# - Encontrar todos los episodios antes de la temporada 8 (sin incluir la temporada 8) y asignarlos a `good_episodes`.
# - Encontrar todos los episodios que se emitieron antes del 1/1/2008 y asignarlos a `early_episodes`.
# - Imprimir los resultados para verificar.

# %%
the_office = pd.read_csv('the_office.csv',sep=";")

# %%
the_office #dataframe
# Out:
#      Season  Episode              Name         Director  \
# 0         1        1             Pilot       Ken Kwapis
# 1         1        2     Diversity Day       Ken Kwapis
# 2         1        3       Health Care  Ken Whittingham
# 3         1        4      The Alliance     Bryan Gordon
# 4         1        5        Basketball     Greg Daniels
# ..      ...      ...               ...              ...
# 196       9       21  Livin' the Dream    Jeffrey Blitz
# 197       9       22          A.A.R.M.     David Rogers
# 198       9       23          A.A.R.M.     David Rogers
# 199       9       24            Finale       Ken Kwapis
# 200       9       25            Finale       Ken Kwapis
#
#                                                 Writer         Airdate  \
# 0    Ricky Gervais & Stephen Merchant and Greg Daniels  March 24, 2005
# 1                                          B. J. Novak  March 29, 2005
# 2                                     Paul Lieberstein   April 5, 2005
# ...

# %% [markdown]
# # Enunciado del ejercicio 2: DataFrame con más de una condición (and - &)
# En este ejercicio trabajarás con el archivo `the_office.csv` que contiene las columnas: Season, Episode, Name, Director, Writer, Airdate, Viewership. Debes:
#
# - Importar el archivo CSV en un DataFrame llamado `office`, indicando que la columna `Airdate` sea interpretada como fecha.
# - Encontrar todos los episodios con una audiencia mayor a 10 millones y que también fueron dirigidos por Jeffrey Blitz, asignando el resultado a `jeffs_episodes`.
# - Encontrar todos los episodios de la temporada 5 con un número de episodio mayor o igual a 13, asignando el resultado a `second_half_of_season_5`.
# - Encontrar todos los episodios que fueron el 6º episodio de su temporada y que se emitieron antes del 01/01/2010, asignando el resultado a `sixth_episodes_of_early_seasons`.
# - Imprimir los resultados para verificar.

# %% [markdown]
# # Enunciado del ejercicio 3: Condición OR en DataFrames
# En este ejercicio trabajarás con el archivo `the_office.csv` que contiene las columnas: Season, Episode, Name, Director, Writer, Airdate, Viewership. Debes:
#
# - Importar el archivo CSV en un DataFrame llamado `office`, indicando que la columna `Airdate` sea interpretada como fecha.
# - Encontrar todos los episodios que fueron de la temporada 4 o dirigidos por Harold Ramis, asignando el resultado a `season_4_or_harold`.
# - Encontrar todos los episodios que tuvieron una audiencia menor a 4 millones o se emitieron en o después del 1 de enero de 2013, asignando el resultado a `low_viewership_or_later_airdate`.
# - Encontrar todos los episodios que fueron el noveno episodio de su temporada o tuvieron el nombre de episodio "Niagara", asignando el resultado a `ninth_or_niagara`.
# - Imprimir los resultados para verificar.

# %% [markdown]
# # Enunciado del ejercicio 4: Método isin() en DataFrames
# En este ejercicio trabajarás con el archivo `billboard.csv` que contiene las columnas: Artist, Album, Released, Genre, Sales. Debes:
#
# - Importar el archivo CSV en un DataFrame llamado `billboard`.
# - Encontrar todos los registros con un artista que sea Michael Jackson, Whitney Houston o Celine Dion, asignando el resultado a `trios`.
# - Encontrar todos los registros con ventas de 25, 35 o 45 millones de copias, asignando el resultado a `fives`.
# - Encontrar todos los registros lanzados en los años 1979, 1989 o 1999, asignando el resultado a `end_of_decade`.
# - Imprimir los resultados para verificar.

# %% [markdown]
# # Enunciado del ejercicio 5: Método between() en DataFrames
# En este ejercicio trabajarás con el archivo `weather.csv` que contiene las columnas: Day, Low Temp, High Temp. Debes:
#
# - Importar el archivo CSV en un DataFrame llamado `weather`, indicando que la columna `Day` sea interpretada como fecha.
# - Extraer las filas donde el día esté entre el 15 y el 22 de abril de 2022 (inclusive), asignando el resultado a `week_of_weather`.
# - Extraer las filas donde la temperatura mínima (`Low Temp`) esté entre 30 y 50, asignando el resultado a `cold_days`.
# - Extraer las filas donde la temperatura máxima (`High Temp`) esté entre 50 y 75, asignando el resultado a `warm_days`.
# - Imprimir los resultados para verificación.
