# %% [markdown]
# Puedes descargar una copia de este cuaderno para editarlo en tu propio Google Drive. Para hacerlo, sigue estos pasos:
#
# 1. Haz clic en el menú "Archivo" en la parte superior izquierda de la pantalla.
# 2. Selecciona "Guardar una copia en Drive".
#
# Esto creará una copia del cuaderno en tu Google Drive, que podrás modificar y ejecutar a tu gusto.

# %% [markdown]
# # Ejercicio 1: Seleccionar una columna de un DataFrame
# Este ejercicio utiliza el archivo `cruise_ships.csv` con las columnas: Name, Operator, Year y Tonnage.
# - Importa el archivo CSV en un DataFrame y asígnalo a la variable `cruise_ships`.
# - Extrae la columna `Operator` y asígnala a la variable `operators`.
# - Extrae la columna `Tonnage` y asígnala a la variable `tonnages`.
# - Extrae la columna `Name` y asígnala a la variable `cruise_names`.
# - Imprime los resultados para verificar.

# %%
import pandas as pd

# %%
cruise_ships = pd.read_csv('cruise_ships', sep = ";")

# %%
cruise_ships.head()
# Out:
#                     Name                        Operator  Year  Tonnage
# 0                 Adonia                         Azamara  2001   30,277
# 1                Adriana                Adriana Shipping  1972     4,49
# 2  Adventure of the Seas   Royal Caribbean International  2001  137,276
# 3         Aegean Goddess       Cruise & Maritime Voyages  1994   55,819
# 4         Aegean Majesty  Optimum Shipmanagement Service  1996   55,451

# %%
operators = cruise_ships['Operator']

# %%
tonnages = cruise_ships['Tonnage']

# %% [markdown]
# # Ejercicio 2: Seleccionar múltiples columnas en un DataFrame
# Este ejercicio utiliza el archivo `chicken_restaurants.csv` con las columnas: Name, Original Location, Year, Headquarters, Locations, Areas Served.
# - Importa el archivo CSV en un DataFrame y asígnalo a la variable `chicken`.
# - Extrae las columnas `Year` y `Locations` en ese orden y asígnalas al DataFrame `years_and_locations`.
# - Extrae las columnas `Locations`, `Name` y `Headquarters` en ese orden y asígnalas al DataFrame `interesting_facts`.
# - Imprime los resultados para verificar.

# %% [markdown]
# # Ejercicio 3: Eliminar filas con valores faltantes (dropna)
# Este ejercicio utiliza el archivo `data.csv` con las columnas: A, B, C y D.
# - Importa el archivo CSV en un DataFrame y asígnalo a la variable `data`.
# - Elimina las filas donde todos los valores están ausentes y asígnalo a `no_empty_rows`.
# - Elimina las filas que tienen un valor faltante en las columnas `B` o `D` y asígnalo a `result`.
# - Imprime los resultados para verificar.

# %% [markdown]
# # Ejercicio 4: Conversión de tipos de datos con astype
# Este ejercicio utiliza el archivo `health.csv` con las columnas: Weight, Height y Blood Type.
# - Importa el archivo CSV en un DataFrame y asígnalo a la variable `health`.
# - Convierte la columna `Weight` a cadenas de texto (string).
# - Convierte la columna `Height` a enteros (int).
# - Convierte la columna `Blood Type` a categorías (category).
# - Imprime el DataFrame resultante para verificar los tipos de datos.

# %% [markdown]
# # Ejercicio 5: Ordenar un DataFrame con sort_values
# Este ejercicio utiliza el archivo `s&p500.csv` con las columnas: Symbol, Security, Sector, Industry, HQ, Founded.
# - Importa el archivo CSV en un DataFrame y asígnalo a la variable `companies`.
# - Ordena el DataFrame por la columna `Industry` en orden ascendente y asígnalo a `by_industry`.
# - Ordena el DataFrame por la columna `HQ` en orden descendente y asígnalo a `by_headquarters_descending`.
# - Ordena el DataFrame primero por `Sector` (descendente) y luego por `Security` (ascendente) y asígnalo a `by_sector_and_security`.
# - Imprime los resultados para verificar.
